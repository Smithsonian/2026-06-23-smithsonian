# %%
import pandas as pd
import plotly.express as px

# %%
print("hello world")

# %%
text = "hello world"

# %%
text.upper()

# %%
df = pd.DataFrame([{"a": 1, "b": 1}])
df

# %%
px.scatter(df, x="a", y="b")
