# %%
    # Change the email to the one you used to register. Case does not matter.
    email = "your@email.address"

    # Do not modify the code below this line #####################################

    import base64

    # Check data files are in the right location
    open("data/0006970-260623161305970.csv")
    open("data/maine_gadm_410.gpkg")

    # Encode email address in b64 as user-specific check that code completed
    print(base64.b64encode(email.lower().strip().encode("utf-8")).decode("utf-8"))
